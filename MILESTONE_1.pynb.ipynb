# %%
# !pip install numpy

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\python.exe

# %%
# !pip install opencv-python matplotlib

# %%
#importing libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os

#TASK 1: Load a 512x512 image
# Initialize with random rgb values
# Display it
image = cv2.imread(r"C:\Users\Admin\Documents\Test\datasets\task1\download.jpg")
height, width, channels = image.shape 
print(type(image))
print("height:", height)
print("width:", width)
print("Channels:", channels)

random_image = np.random.randint(0, 256, (height, width, channels), dtype=np.uint8)
cv2.imwrite('random_rgb_image.jpg', random_image)
plt.imshow(cv2.cvtColor(random_image, cv2.COLOR_BGR2RGB))
plt.title("Random Image")
plt.axis('off')
plt.show()

#TASK 2: Load a 512x512 image
# Initialize with random rgb values
# Tranform the image into a grayscale image
# Display it

import matplotlib.pyplot as plt
image = cv2.imread(r"C:\Users\Admin\Documents\Test\datasets\task1\download.jpg")
plt.imshow(image, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()

#TASK 3: Load the Fingerprint Image datasets\task3\1.tiff
# Display it
# Load the Fingerprint Image datasets\task3\2.tiff
# Display it
img1= cv2.imread(r"C:\Users\Admin\Documents\Test\datasets\task3\1.tiff")
img2= cv2.imread(r"C:\Users\Admin\Documents\Test\datasets\task3\2.tiff")
plt.imshow(img1)
plt.title("First fingerprint image")
plt.axis('off') 
plt.show()

plt.imshow(img2)
plt.title("Second fingerprint image")
plt.axis('off') 
plt.show()
# Out:
# <class 'numpy.ndarray'>
# height: 148
# width: 185
# Channels: 3

# %%
# #TASK 2

# import matplotlib.pyplot as plt
# image = cv2.imread(r"C:\Users\Admin\Documents\Test\fingerprint.png")

# plt.imshow(image, cmap='gray')
# plt.title("Grayscale Image")
# plt.axis('off')
# plt.show()
